# %% [markdown]
# # Dictionary Practice
#
# Below is a series of problems divided into several categories.  We expect students from CS111 to be able to complete all the core problems.  We also have a series of problems dealing with election data.  Dictionaries are often used in the context of real data so this is good practice.  Finally, we have a series of challenge problems for those who complete the main tasks.

# %% [markdown]
# ## Core Problems
#
# ### Accessing

# %%
dct = {
    'a': 1,
    1 : True,
    (1, ) : [1, 'a', True]
}

# %% [markdown]
# Predict what the following results will be **before** executing the cell.

# %%
dct['a']
# Out:
# 1

# %%
dct[1]
# Out:
# True

# %%
dct[(1, )]
# Out:
# [1, 'a', True]

# %%
dct[(1, )][1]
# Out:
# 'a'

# %%
dct.get(1)
# Out:
# True

# %%
dct.get(8, False)
# Out:
# False

# %% [markdown]
# Challenge: The two below are tricky!

# %%
dct[dct['a']]
# Out:
# True

# %%
dct[dct[(1,)][1]]
# Out:
# 1

# %% [markdown]
# ### Mutating Dictionaries
#
# Consider the dictionary below.  Follow the mutations below and predict what the final outcome of the dictionary will be.

# %%
dct = {
    'Andy' : 144,
    'Sohie' : "Cancun"
}

# %% [markdown]
# Below are some mutations for the dictionary `dct`.

# %%
dct["Andy"] = 146
dct["Peter"] = 145
dct["Truth"] = dct["Andy"] > dct["Peter"]

# %% [markdown]
# Predict the outcome of the mutations **before** checking your answer below.

# %%
dct
# Out:
# {'Andy': 146, 'Sohie': 'Cancun', 'Peter': 145, 'Truth': True}

# %% [markdown]
# Predict what the dictionary will look like after running the line below.

# %%
dct.update({"Andy": 147, "Sohie": "Bahamas", "Parker": "Woof"})

# %% [markdown]
# Predict the outcome of the mutations **before** checking your answer below.

# %%
dct
# Out:
# {'Andy': 147,
#  'Sohie': 'Bahamas',
#  'Peter': 145,
#  'Truth': True,
#  'Parker': 'Woof'}

# %% [markdown]
# ### Who Won?

# %% [markdown]
# Below you will write two functions to determine whether a team beat another team in some competition.  A team is represented by a dictionary where the keys are the names of the players and the values are the scores that each player contributes to the overall team score.  Below is an example of a team dictionary.
#
# ```
# {"Andy":10, "Sohie":12}
# ```
#
# Write a function `teamTotal` that takes a team dictionary and reports the overall score of the team.  For example, a call to `teamTotal({"Andy":10, "Sohie":12})` returns a value of 22.

# %%
def teamTotal(teamDct):
    # Your code here
    counter = 0
    for playerScore in teamDct.values():
        counter += playerScore
    return counter

# %%
teamTotal({"Andy":10, "Sohie":12}) # should return 22
# Out:
# 22

# %%
teamTotal({"Andy":10}) # should return 10
# Out:
# 10

# %%
teamTotal({}) # should return 0
# Out:
# 0

# %% [markdown]
# Write a function called `whoWon` that takes two team dictionaries and prints out which team won.  If the result is a tie, the function should print out that a tie occurred.

# %%
def whoWon(team1, team2):
    # Your code here
    teamOneTotal = teamTotal(team1)
    teamTwoTotal = teamTotal(team2)
    if teamOneTotal > teamTwoTotal:
        print("Team 1 won!")
    elif teamOneTotal < teamTwoTotal:
        print("Team 2 won!")
    else:
        print("It's a tie!")

# %%
whoWon({"Andy": 4}, {"Sohie": 5}) # should print that team 2 won
# Out:
# Team 2 won!

# %%
whoWon({"Andy": 4}, {}) # should print that team 1 won
# Out:
# Team 1 won!

# %%
whoWon({"Andy": 4, "Parker": 45}, {"Sohie": 5}) # should print that team 1 won
# Out:
# Team 1 won!

# %%
whoWon({"Andy": 4, "Parker": 45}, {"Sohie": 5, "Peter": 40, "Djikstra" : 45}) # should print that team 2 won
# Out:
# Team 2 won!

# %%
whoWon({}, {}) # should print that it is a tie
# Out:
# It's a tie!

# %%
whoWon({"Andy" : 4, "Veeksha" : 6}, {"Leda" : 10}) # should print that it is a tie
# Out:
# It's a tie!

# %% [markdown]
# ## Working With Data
#
# Below is a piece of code to import some data about Senate elections from 1976-2018 and store those results in a dictionary called `senateDct`.  `senateDct` is a dictionary with every Senate election excluding special runoff elections.  Every key-value pair in `senateDct` contains the information for an election in a particular state during a particular year.  The keys to the Senate dictionary are a tuple of year and state and the values are a dictionary containing the information for a particular year.  For example, below is the information for the 1978 Senate election in Kansas.  Note that this key-value pair is one of many in the larger dictionary `senateDct`.
#
# ```
# (1978, 'Kansas'): {
#     'names': ['Nancy Landon Kassebaum', 'James R. Maher', 'Russell Mikels', 'Bill Roy'],
#     'parties': ['republican', 'conservative', 'prohibition', 'democrat'],
#     'writein': [False, False, False, False],
#     'votes': [403354, 22497, 5386, 317602],
#     'totalvotes': 748839
# }
# ```
#
# The key `'names'` lists all the candidates in that election. The key `'parties'` lists all the parties of each candidate in the same order as the names.  Therefore, in this example, Nancy Kassebaum is the Republican and Bill Roy is the Democrat.  The key `'writeins'` has a value listing whether the candidates were writeins (also preserving the same order).  The key `'votes'` also lists the votes of each candidate in the same order as the names.  So Nancy Kassebaum won this election with 403,354 votes.
#
# **IMPORTANT**: When working with the `senateDct` below, do not mutate or change the dictionary or any of its sub-values!

# %%
import csv

senateDct = {}
with open("senate.csv", newline="", encoding="utf8") as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        year, state, special, name, party, writein, votes, totalvotes = row
        if year == "year": continue # ignore row headers
        year = int(year)
        special = False if special == "FALSE" else True
        writein = False if writein == "FALSE" else True
        votes = int(votes)
        totalvotes = int(totalvotes)
        
        if special: continue # ignore special elections for ease
        if (year, state) not in senateDct: 
            senateDct[(year, state)] = {
                "names":[name], 
                "parties":[party], 
                "writeins":[writein],
                "votes":[votes],
                "totalvotes":votes
            }
        else:
            electionDct = senateDct[(year, state)]
            electionDct["names"].append(name)
            electionDct["parties"].append(party)
            electionDct["writeins"].append(writein)
            electionDct["votes"].append(votes)
            electionDct["totalvotes"] += votes

senateDct
# Out:
# {(1976,
#   'Arizona'): {'names': ['Sam Steiger',
#    'Wm. Mathews Feighan',
#    'Dennis DeConcini',
#    'Allan Norwitz',
#    'Bob Field'], 'parties': ['republican',
#    'independent',
#    'democrat',
#    'libertarian',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [321236, 1565, 400334, 7310, 10765], 'totalvotes': 741210},
#  (1976,
#   'California'): {'names': ['Jack McCoy',
#    'S. I. (Sam) Hayakawa',
#    'John V. Tunney',
#    'Omari Musa',
#    'David Wald'], 'parties': ['american independent',
#    'republican',
#    'democrat',
#    'independent',
#    'peace and freedom'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [82739,
#    3748973,
#    3502862,
#    31629,
#    104383], 'totalvotes': 7470586},
#  (1976,
#   'Connecticut'): {'names': ['Lowell P. Weicker, Jr.',
#    'scatter',
#    'Robert Barnabei',
#    'Gloria Schaffer'], 'parties': ['republican',
#    '',
#    'american independent',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [785683,
#    558,
#    14407,
#    561018], 'totalvotes': 1361666},
#  (1976,
#   'Delaware'): {'names': ['Thomas C. Maloney',
#    'William V. Roth, Jr.',
#    'Donald G. Gies',
#    'John A. Massimilla',
#    'Joseph F. McInerney'], 'parties': ['democrat',
#    'republican',
#    'american',
#    'prohibition',
#    'none'], 'writeins': [False, False, False, False, False], 'votes': [98042,
#    125454,
#    646,
#    216,
#    437], 'totalvotes': 224795},
#  (1976, 'Florida'): {'names': ['Lawton Chiles', 'scatter', 'John Grady'],
#   'parties': ['democrat', '', 'republican'],
#   'writeins': [False, False, False],
#   'votes': [1799518, 130, 1057886],
#   'totalvotes': 2857534},
#  (1976,
#   'Hawaii'): {'names': ['Spark M. Matsunaga',
#    'James D. Kimmel',
#    'William Quinn',
#    'Anthony N. Hodges',
#    'Rockne Johnson'], 'parties': ['democrat',
#    'independent',
#    'republican',
#    'prohibition',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [162305, 1433, 122724, 14226, 1404], 'totalvotes': 302092},
#  (1976,
#   'Indiana'): {'names': ['Richard G. Lugar',
#    'Vance Hartke',
#    'Don L. Lee',
#    'David Lee Hoagland'], 'parties': ['republican',
#    'democrat',
#    'independent',
#    'u.s. labor'], 'writeins': [False, False, False, False], 'votes': [1275833,
#    868522,
#    14321,
#    2511], 'totalvotes': 2161187},
#  (1976, 'Maine'): {'names': ['Robert A. G. Monks', 'Edmund S. Muskie'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [193489, 292704],
#   'totalvotes': 486193},
#  (1976,
#   'Maryland'): {'names': ['J. Glenn Beall, Jr.',
#    'Paul S. Sarbanes',
#    'Bruce Bradley'], 'parties': ['republican',
#    'democrat',
#    'independent'], 'writeins': [False, False, False], 'votes': [530439,
#    772101,
#    62750], 'totalvotes': 1365290},
#  (1976,
#   'Massachusetts'): {'names': ['Carol Henderson Evans',
#    'scatter',
#    'Michael S. Robertson',
#    'H. Graham Lowry',
#    'Edward M. Kennedy'], 'parties': ['socialist workers',
#    '',
#    'republican',
#    'u.s. labor',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [26283, 157, 722641, 15517, 1726657], 'totalvotes': 2491255},
#  (1976,
#   'Michigan'): {'names': ['Bette Jane Erwin',
#    'Theodore G. Albert',
#    'Marvin L. Esch',
#    'Donald W. Riegle, Jr.',
#    'Frank Girard',
#    'Paula L. Reimers',
#    'Peter A. Signorelli'], 'parties': ['libertarian',
#    'human rights',
#    'republican',
#    'democrat',
#    'socialist labor',
#    'socialist workers',
#    'u.s. labor'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [8842,
#    7281,
#    1635087,
#    1831031,
#    2554,
#    3399,
#    2218], 'totalvotes': 3490412},
#  (1976,
#   'Minnesota'): {'names': ['Robin E. Miller',
#    'Bill Peterson',
#    'Matt Savola',
#    'Jerry Brekke',
#    'Paul Helm',
#    'Hubert H. Humphrey'], 'parties': ['libertarian',
#    'socialist workers',
#    'communist',
#    'republican',
#    'american',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [5476,
#    9380,
#    2214,
#    478602,
#    125612,
#    1290736], 'totalvotes': 1912020},
#  (1976, 'Mississippi'): {'names': ['John C. Stennis'],
#   'parties': ['democrat'],
#   'writeins': [False],
#   'votes': [554433],
#   'totalvotes': 554433},
#  (1976,
#   'Missouri'): {'names': ['John C. Danforth',
#    'Warren E. Hearnes',
#    'Lawrene (Red) Petty'], 'parties': ['republican',
#    'democrat',
#    'independent'], 'writeins': [False, False, False], 'votes': [1090067,
#    813571,
#    10822], 'totalvotes': 1914460},
#  (1976, 'Montana'): {'names': ['Stanley C. Burger', 'John Melcher'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [115213, 206232],
#   'totalvotes': 321445},
#  (1976,
#   'Nebraska'): {'names': ['NA',
#    'scatter',
#    'John Y. McCollister',
#    'Edward Zorinsky'], 'parties': ['NA',
#    '',
#    'republican',
#    'democrat'], 'writeins': [True, False, False, False], 'votes': [58,
#    163,
#    279284,
#    313805], 'totalvotes': 593310},
#  (1976,
#   'Nevada'): {'names': ['Byron D. Young',
#    'David Towell',
#    'Other',
#    'Dan Becan',
#    'Howard W. Cannon'], 'parties': ['independent american',
#    'republican',
#    '',
#    'libertarian',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [3619, 63471, 5288, 2307, 127214], 'totalvotes': 201899},
#  (1976,
#   'New Jersey'): {'names': ['Leif Johnson',
#    'Hannibal Cundari',
#    'Harrison A. Williams, Jr.',
#    'Bernardo S. Doganiero',
#    'David F. Norcross'], 'parties': ['labor',
#    'libertarian',
#    'democrat',
#    'socialist labor',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [6650, 19907, 1681140, 9185, 1054508], 'totalvotes': 2771390},
#  (1976,
#   'New Mexico'): {'names': ['Ernesto B. Borunda',
#    'Joseph M. Montoya',
#    'Malcolm "Matt" Dillon',
#    'Harrison "Jack" Schmitt'], 'parties': ['la raza unida',
#    'democrat',
#    'american',
#    'republican'], 'writeins': [False, False, False, False], 'votes': [1087,
#    176382,
#    906,
#    234681], 'totalvotes': 413056},
#  (1976,
#   'New York'): {'names': ['Marcia Gallo',
#    'Daniel Patrick Moynihan',
#    'James L. Buckley',
#    'Elijah C. Boyd',
#    'Herbert Aptheker',
#    'Martin E. Nixon',
#    'Other',
#    'James L. Buckley',
#    'Daniel Patrick Moynihan'], 'parties': ['socialist workers',
#    'liberal',
#    'conservative',
#    'labor',
#    'communist',
#    'libertarian',
#    '',
#    'republican',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [16350,
#    184083,
#    311494,
#    6716,
#    25141,
#    10943,
#    348498,
#    2525139,
#    3238511], 'totalvotes': 6666875},
#  (1976,
#   'North Dakota'): {'names': ['Robert Stroup',
#    'Quentin N. Burdick',
#    'Clarence Haggard'], 'parties': ['republican',
#    'democrat',
#    'american'], 'writeins': [False, False, False], 'votes': [103466,
#    175772,
#    3824], 'totalvotes': 283062},
#  (1976,
#   'Ohio'): {'names': ['Emma Lila Fundaburk',
#    'Howard M. Metzenbaum',
#    'Robert Taft, Jr.',
#    'Melisa Singler',
#    'Donald E. Babcock',
#    "John O'Neill"], 'parties': ['independent',
#    'democrat',
#    'republican',
#    'socialist workers',
#    'american',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [33285,
#    1941113,
#    1823774,
#    31805,
#    36979,
#    53657], 'totalvotes': 3920613},
#  (1976,
#   'Pennsylvania'): {'names': ['H. John Heinz III',
#    'Frederick W. Stanton',
#    'Bernard Salera',
#    'Frank Kinces',
#    'Andrew J. Watson',
#    'William J. Green',
#    'Other'], 'parties': ['republican',
#    'socialist workers',
#    'labor',
#    'communist',
#    'constitution',
#    'democrat',
#    ''], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [2381891,
#    5484,
#    3637,
#    2097,
#    26028,
#    2126977,
#    239], 'totalvotes': 4546353},
#  (1976,
#   'Rhode Island'): {'names': ['Richard P. Lorber',
#    'John H. Chafee',
#    'Margaret R. Cann'], 'parties': ['democrat',
#    'republican',
#    'communist'], 'writeins': [False, False, False], 'votes': [167665,
#    230329,
#    912], 'totalvotes': 398906},
#  (1976,
#   'Tennessee'): {'names': ['Mark Clark Bates',
#    'Willie C. Jacox',
#    'NA',
#    'James R. Sasser',
#    'Arnold Joseph Zandie',
#    'Bill Brock'], 'parties': ['independent',
#    'independent',
#    'NA',
#    'democrat',
#    'independent',
#    'republican'], 'writeins': [False,
#    False,
#    True,
#    False,
#    False,
#    False], 'votes': [5137,
#    1406,
#    31,
#    751180,
#    1061,
#    673231], 'totalvotes': 1432046},
#  (1976,
#   'Texas'): {'names': ['Pedro Vasquez',
#    'Marjorie P. Gallion',
#    'Alan Steelman',
#    'Lloyd Bentsen'], 'parties': ['socialist workers',
#    'american',
#    'republican',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [20549,
#    17355,
#    1636370,
#    2199956], 'totalvotes': 3874230},
#  (1976,
#   'Utah'): {'names': ['Steve Trotter',
#    'George Merl Batchelor',
#    'Orrin G. Hatch',
#    'Frank E. Moss'], 'parties': ['libertarian',
#    'american',
#    'republican',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [3026,
#    4913,
#    290221,
#    223948], 'totalvotes': 522108},
#  (1976,
#   'Vermont'): {'names': ['Robert T. Stafford',
#    'scatter',
#    'Thomas P. Salmon',
#    'Nancy Kaufman'], 'parties': ['republican',
#    '',
#    'democrat',
#    'liberty union'], 'writeins': [False, False, False, False], 'votes': [94481,
#    96,
#    85682,
#    8801], 'totalvotes': 189060},
#  (1976,
#   'Virginia'): {'names': ['NA',
#    'Martin H. Perper',
#    'E. R. (Bud) Zumwalt',
#    'Harry F. Byrd, Jr.'], 'parties': ['NA',
#    'independent',
#    'democrat',
#    'independent'], 'writeins': [True, False, False, False], 'votes': [154,
#    70559,
#    596009,
#    890778], 'totalvotes': 1557500},
#  (1976,
#   'Washington'): {'names': ['William F. Wertz, Jr.',
#    'Dave Smith',
#    'Karl Bermann',
#    'Henry M. Jackson',
#    'Richard K. Kenney',
#    'George M. Brown'], 'parties': ['labor',
#    'independent',
#    'socialist workers',
#    'democrat',
#    'libertarian',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [3389,
#    28182,
#    7402,
#    1071219,
#    19373,
#    361546], 'totalvotes': 1491111},
#  (1976, 'West Virginia'): {'names': ['Robert C. Byrd'],
#   'parties': ['democrat'],
#   'writeins': [False],
#   'votes': [566359],
#   'totalvotes': 566359},
#  (1976,
#   'Wisconsin'): {'names': ['Michael A. MacLaurin',
#    'William O. Hart',
#    'Robert E. Nordlander',
#    'William Proxmire',
#    'Robert Schwarz',
#    'scatter',
#    'Stanley York'], 'parties': ['u.s. labor',
#    'democratic socialist',
#    'socialist labor',
#    'democrat',
#    'socialist workers',
#    '',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [2148,
#    7354,
#    1731,
#    1396970,
#    4876,
#    202,
#    521902], 'totalvotes': 1935183},
#  (1976, 'Wyoming'): {'names': ['Gale McGee', 'Malcolm Wallop'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [70558, 84810],
#   'totalvotes': 155368},
#  (1978, 'Alabama'): {'names': ['Jerome B. Couch', 'Howell Heflin'],
#   'parties': ['prohibition', 'democrat'],
#   'writeins': [False, False],
#   'votes': [34951, 547054],
#   'totalvotes': 582005},
#  (1978, 'Alaska'): {'names': ['Donald Hobbs', 'NA', 'Ted Stevens'],
#   'parties': ['democrat', 'NA', 'republican'],
#   'writeins': [False, True, False],
#   'votes': [29574, 384, 92783],
#   'totalvotes': 122741},
#  (1978,
#   'Arkansas'): {'names': ['John Graham Black',
#    'NA',
#    'David Pryor',
#    'Tom Kelly'], 'parties': ['independent',
#    'NA',
#    'democrat',
#    'republican'], 'writeins': [False, True, False, False], 'votes': [37211,
#    113,
#    395506,
#    84308], 'totalvotes': 517138},
#  (1978,
#   'Colorado'): {'names': ['John Shue ',
#    'Vedder V. Dron',
#    'Floyd K. Haskell',
#    'William L. Armstrong'], 'parties': ['national statesman',
#    'united states party',
#    'democrat',
#    'republican'], 'writeins': [False, False, False, False], 'votes': [2518,
#    5789,
#    330148,
#    480801], 'totalvotes': 819256},
#  (1978,
#   'Delaware'): {'names': ['Joseph R. Biden Jr.',
#    'Donald G. Gies',
#    'James H. Baxter Jr.'], 'parties': ['democrat',
#    'american',
#    'republican'], 'writeins': [False, False, False], 'votes': [93930,
#    1663,
#    66479], 'totalvotes': 162072},
#  (1978, 'Georgia'): {'names': ['John W. Stokes', 'Sam Nunn'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [108808, 536320],
#   'totalvotes': 645128},
#  (1978, 'Idaho'): {'names': ['Dwight Jensen', 'James A. McClure'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [89635, 194412],
#   'totalvotes': 284047},
#  (1978,
#   'Illinois'): {'names': ['Patricia Grogan',
#    'Alex Smith',
#    'Bruce Lee Green',
#    'NA',
#    'Charles H. Perey',
#    'Gerald Rose'], 'parties': ['socialist workers',
#    'democrat',
#    'libertarian',
#    'NA',
#    'republican',
#    'socialist labor'], 'writeins': [False,
#    False,
#    False,
#    True,
#    False,
#    False], 'votes': [15922,
#    1448187,
#    16320,
#    159,
#    1698711,
#    5465], 'totalvotes': 3184764},
#  (1978,
#   'Iowa'): {'names': ['Roger W. Jepsen',
#    'Ben L. Olson',
#    'Dick Clark',
#    'Gerald Leo Baker'], 'parties': ['republican',
#    'libertarian',
#    'democrat',
#    'independent'], 'writeins': [False, False, False, False], 'votes': [421598,
#    3689,
#    395066,
#    4223], 'totalvotes': 824576},
#  (1978,
#   'Kansas'): {'names': ['Nancy Landon Kassebaum',
#    'James R. Maher',
#    'Russell Mikels',
#    'Bill Roy'], 'parties': ['republican',
#    'conservative',
#    'prohibition',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [403354,
#    22497,
#    5386,
#    317602], 'totalvotes': 748839},
#  (1978,
#   'Kentucky'): {'names': ['NA',
#    'Walter D. Huddleston',
#    'Louie Guenthner Jr. ',
#    'Anthony Albert McCord'], 'parties': ['NA',
#    'democrat',
#    'republican',
#    'american'], 'writeins': [True, False, False, False], 'votes': [43,
#    290730,
#    175766,
#    10244], 'totalvotes': 476783},
#  (1978, 'Louisiana'): {'names': ['J. Bennett Johnston Jr. '],
#   'parties': ['democrat'],
#   'writeins': [False],
#   'votes': [1],
#   'totalvotes': 1},
#  (1978,
#   'Maine'): {'names': ['William D. Hathaway',
#    'John J. Jannace',
#    'William S. Cohen',
#    'Hayes E. Gahagan',
#    'Plato Truman'], 'parties': ['democrat',
#    'independent',
#    'republican',
#    'independent',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [127327, 5553, 212294, 27824, 2116], 'totalvotes': 375114},
#  (1978,
#   'Massachusetts'): {'names': ['Other',
#    'Paul E. Tsongas',
#    'Edward W. Brooke'], 'parties': ['',
#    'democrat',
#    'republican'], 'writeins': [False, False, False], 'votes': [1833,
#    1093283,
#    890584], 'totalvotes': 1985700},
#  (1978, 'Michigan'): {'names': ['Carl Levin', 'Robert P. Griffin', 'scatter'],
#   'parties': ['democrat', 'republican', ''],
#   'writeins': [False, False, False],
#   'votes': [1484193, 1362165, 272],
#   'totalvotes': 2846630},
#  (1978,
#   'Minnesota'): {'names': ['Brian John Coyle',
#    'Jean T. Brust',
#    'Wendell Anderson',
#    'Sal Carlone',
#    'Leonard Richards',
#    'William Peterson',
#    'NA',
#    'Rudolph E. Boschwitz'], 'parties': ['public interest independent',
#    'workers',
#    'democrat',
#    'american',
#    'libertarian',
#    'socialist workers',
#    'NA',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False], 'votes': [8083,
#    3891,
#    638375,
#    23261,
#    2992,
#    9856,
#    72,
#    894092], 'totalvotes': 1580622},
#  (1978,
#   'Mississippi'): {'names': ['Maurice Dantin',
#    'James Charles Evers',
#    'Henry Jay Kirksey',
#    'Thad Cochran'], 'parties': ['democrat',
#    'independent',
#    'independent',
#    'republican'], 'writeins': [False, False, False, False], 'votes': [187541,
#    133646,
#    1747,
#    267302], 'totalvotes': 590236},
#  (1978, 'Montana'): {'names': ['Max Baucus', 'Larry Williams'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [160353, 127589],
#   'totalvotes': 287942},
#  (1978, 'Nebraska'): {'names': ['Donald Eugene Shasten', 'James J. Exon'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [159706, 334096],
#   'totalvotes': 493802},
#  (1978,
#   'New Hampshire'): {'names': ['Craig Franklin',
#    'Gordon J. Humphrey',
#    'Thomas J. McIntyre'], 'parties': ['libertarian',
#    'republican',
#    'democrat'], 'writeins': [False, False, False], 'votes': [2070,
#    133745,
#    127945], 'totalvotes': 263760},
#  (1978,
#   'New Jersey'): {'names': ['Jack Moyers',
#    'Jeffrey Bell',
#    'Bill Bradley',
#    'Robert Brown',
#    'J. M. Carter Jr. ',
#    'Herbert Harry Shaw',
#    'William R. Thorn',
#    'Jasper C. Gould',
#    'Alice Conner',
#    'Paul Ferguson',
#    'Bill Gahres'], 'parties': ['independent',
#    'republican',
#    'democrat',
#    'labor',
#    'independent',
#    'independent',
#    'independent',
#    'independent',
#    'independent',
#    'independent',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [3809,
#    844200,
#    1082960,
#    3656,
#    3618,
#    4736,
#    2776,
#    2955,
#    2384,
#    2604,
#    3817], 'totalvotes': 1957515},
#  (1978, 'New Mexico'): {'names': ['Toney Anaya', 'Pete V. Domenici'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [160045, 183442],
#   'totalvotes': 343487},
#  (1978, 'North Carolina'): {'names': ['Jesse Helms', 'John Randolph Ingram'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [619151, 516663],
#   'totalvotes': 1135814},
#  (1978,
#   'Oklahoma'): {'names': ['Robert B. Kamm',
#    'Glenn E. Hager',
#    'Paul Edward Trent',
#    'Richard King Carter',
#    'David Lyle Boren',
#    'Riley Donica'], 'parties': ['republican',
#    'independent',
#    'independent',
#    'independent',
#    'democrat',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [247857,
#    3875,
#    3015,
#    2209,
#    493953,
#    3355], 'totalvotes': 754264},
#  (1978, 'Oregon'): {'names': ['NA', 'Mark Hatfield', 'Vern Cook'],
#   'parties': ['NA', 'republican', 'democrat'],
#   'writeins': [True, False, False],
#   'votes': [737, 550165, 341616],
#   'totalvotes': 892518},
#  (1978, 'Rhode Island'): {'names': ['Claiborne Pell', 'James G. Reyonlds'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [229557, 76061],
#   'totalvotes': 305618},
#  (1978, 'South Carolina'): {'names': ['Strom Thurmond', 'Charles D. Ravenel'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [351917, 280146],
#   'totalvotes': 632063},
#  (1978, 'South Dakota'): {'names': ['Don Barnett', 'Larry Pressler'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [84767, 170832],
#   'totalvotes': 255599},
#  (1978,
#   'Tennessee'): {'names': ['Howard H. Baker',
#    'Thomas J. Anderson',
#    'Jane Eskind',
#    'NA',
#    'Fern Lucius Keasler'], 'parties': ['republican',
#    'independent',
#    'democrat',
#    'NA',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    True,
#    False], 'votes': [642644, 45908, 466228, 71, 2243], 'totalvotes': 1157094},
#  (1978,
#   'Texas'): {'names': ['Miguel Pendas',
#    'Robert Krueger',
#    'John G. Tower',
#    'Other',
#    'Luis A. Diaz de Loen'], 'parties': ['socialist workers',
#    'democrat',
#    'republican',
#    '',
#    'la raza unida'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [4018,
#    1139149,
#    1151376,
#    128,
#    17869], 'totalvotes': 2312540},
#  (1978,
#   'Virginia'): {'names': ['Andrew P. Miller',
#    'John William Warner',
#    'NA'], 'parties': ['democrat', 'republican', 'NA'], 'writeins': [False,
#    False,
#    True], 'votes': [608511, 613232, 513], 'totalvotes': 1222256},
#  (1978,
#   'West Virginia'): {'names': ['Arch A. Moore Jr. ',
#    'Jennings Randolph'], 'parties': ['republican',
#    'democrat'], 'writeins': [False, False], 'votes': [244317,
#    249034], 'totalvotes': 493351},
#  (1978, 'Wyoming'): {'names': ['Raymond B. Whitaker', 'Alan Kooi Simpson'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [82908, 50456],
#   'totalvotes': 133364},
#  (1980,
#   'Alabama'): {'names': ['Jim Folsom Jr.',
#    'Jeremiah Denton',
#    'Sallie M. Hadnott',
#    'William A. Crew',
#    'Michael R.A. Erdey',
#    'Jim Partain',
#    'Mohammed Oliver'], 'parties': ['democrat',
#    'republican',
#    'national democratic party of alabama',
#    'libertarian',
#    'conservative',
#    'statesman',
#    'socialist workers'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [610175,
#    650362,
#    2973,
#    13098,
#    15989,
#    2649,
#    1511], 'totalvotes': 1296757},
#  (1980, 'Alaska'): {'names': ['Clark S. Gruening', 'NA', 'Frank H. Murkowski'],
#   'parties': ['democrat', 'NA', 'republican'],
#   'writeins': [False, True, False],
#   'votes': [72007, 596, 84159],
#   'totalvotes': 156762},
#  (1980,
#   'Arizona'): {'names': ['NA',
#    'Josefina Otero',
#    'Barry Goldwater',
#    'Fred R. Esser',
#    'Lorenzo Torrez',
#    'Bill Schulz'], 'parties': ['NA',
#    'socialist workers',
#    'republican',
#    'libertarian',
#    'people before profits',
#    'democrat'], 'writeins': [True,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [13,
#    3266,
#    432371,
#    12008,
#    3608,
#    422972], 'totalvotes': 874238},
#  (1980, 'Arkansas'): {'names': ['NA', 'Dale Bumpers', 'Bill Clark'],
#   'parties': ['NA', 'democrat', 'republican'],
#   'writeins': [True, False, False],
#   'votes': [331, 477905, 330576],
#   'totalvotes': 808812},
#  (1980,
#   'California'): {'names': ['Paul Gann',
#    'James C. (Jim) Griffin',
#    'David Wald',
#    'David Bergland',
#    'Alan Cranston'], 'parties': ['republican',
#    'american independent',
#    'peace and freedom',
#    'libertarian',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [3091671, 129573, 196260, 202410, 4704098], 'totalvotes': 8324012},
#  (1980,
#   'Colorado'): {'names': ['Earl Higgerson',
#    'Henry John Olshaw',
#    'Gary Hart',
#    'Mary Estill Buchanan'], 'parties': ['statesman',
#    'unaffiliated-american',
#    'democrat',
#    'republican'], 'writeins': [False, False, False, False], 'votes': [7265,
#    4081,
#    590501,
#    571295], 'totalvotes': 1173142},
#  (1980,
#   'Connecticut'): {'names': ['NA',
#    'Louis Zemel',
#    'Christopher J. Dodd',
#    'Gerard G. Brennan',
#    'James L. Buckley'], 'parties': ['NA',
#    'citizens',
#    'democrat',
#    'libertarian',
#    'republican'], 'writeins': [True,
#    False,
#    False,
#    False,
#    False], 'votes': [114, 4772, 763969, 5336, 581884], 'totalvotes': 1356075},
#  (1980, 'Florida'): {'names': ['NA', 'Bill Gunter', 'Paula Hawkins'],
#   'parties': ['NA', 'democrat', 'republican'],
#   'writeins': [True, False, False],
#   'votes': [159, 1705409, 1822460],
#   'totalvotes': 3528028},
#  (1980, 'Georgia'): {'names': ['Herman E. Talmadge', 'Mack Mattingly'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [776143, 803686],
#   'totalvotes': 1579829},
#  (1980,
#   'Hawaii'): {'names': ['Bud Shasteen',
#    'Daniel K. Inouye',
#    'Cooper Brown'], 'parties': ['libertarian',
#    'democrat',
#    'republican'], 'writeins': [False, False, False], 'votes': [10453,
#    224485,
#    53068], 'totalvotes': 288006},
#  (1980, 'Idaho'): {'names': ['Steve Symms', 'Frank Church', 'Larry Fullmer'],
#   'parties': ['republican', 'democrat', 'libertarian'],
#   'writeins': [False, False, False],
#   'votes': [218701, 214439, 6507],
#   'totalvotes': 439647},
#  (1980,
#   'Illinois'): {'names': ["David C. O'Neal",
#    'Alan J. Dixon',
#    'Sidney Lens',
#    'Bruce Green',
#    'Michael Soriano',
#    'NA',
#    'Charles F. Wilson',
#    'Burton Lee Artz'], 'parties': ['republican',
#    'democrat',
#    'citizens',
#    'libertarian',
#    'workers world',
#    'NA',
#    'communist',
#    'socialist workers'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False], 'votes': [1946296,
#    2565302,
#    19213,
#    29328,
#    5626,
#    96,
#    11453,
#    2715], 'totalvotes': 4580029},
#  (1980, 'Indiana'): {'names': ['Birch Bayh', 'Dan Quayle'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [1015962, 1182414],
#   'totalvotes': 2198376},
#  (1980,
#   'Iowa'): {'names': ['Charles E. Grassley',
#    'Garry De Young',
#    'John Ingram Henderson',
#    'Robert V. Hengerer',
#    'John Culver'], 'parties': ['republican',
#    'by petition',
#    'by petition',
#    'libertarian',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [683014, 5858, 2336, 4233, 581545], 'totalvotes': 1276986},
#  (1980, 'Kansas'): {'names': ['Bob Dole', 'John Simpson'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [598686, 340271],
#   'totalvotes': 938957},
#  (1980, 'Kentucky'): {'names': ['Wendell H. Ford', 'Mary Louise Foust'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [720891, 386029],
#   'totalvotes': 1106920},
#  (1980,
#   'Louisiana'): {'names': ['Naomi Bracey',
#    'Louis Woody Jenkins',
#    'Russell B. Long',
#    'Jerry C. Bardwell',
#    'Robert Max Ross'], 'parties': ['no party',
#    'democrat',
#    'democrat',
#    'republican',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [6374, 325922, 484770, 13739, 10208], 'totalvotes': 841013},
#  (1980,
#   'Maryland'): {'names': ['Charles McC. Mathias Jr. ',
#    'Edward T. Conroy'], 'parties': ['republican',
#    'democrat'], 'writeins': [False, False], 'votes': [850970,
#    435118], 'totalvotes': 1286088},
#  (1980,
#   'Missouri'): {'names': ['Gene McNary',
#    'Thomas F. Eagleton',
#    'Martha Pettis'], 'parties': ['republican',
#    'democrat',
#    'socialist workers'], 'writeins': [False, False, False], 'votes': [985399,
#    1074859,
#    6707], 'totalvotes': 2066965},
#  (1980, 'Nevada'): {'names': ['Allen Hacker', 'Paul Laxalt', 'Mary Gojack'],
#   'parties': ['libertarian', 'republican', 'democrat'],
#   'writeins': [False, False, False],
#   'votes': [6920, 144224, 92129],
#   'totalvotes': 243273},
#  (1980, 'New Hampshire'): {'names': ['Warren Rudman', 'John A. Durkin', 'NA'],
#   'parties': ['republican', 'democrat', 'NA'],
#   'writeins': [False, False, True],
#   'votes': [195559, 179455, 46],
#   'totalvotes': 375060},
#  (1980,
#   'New York'): {'names': ['Richard Savadel',
#    'Thomas Soto',
#    "Alfonse M. D'Amato",
#    "Alfonse M. D'Amato",
#    "Alfonse M. D'Amato",
#    'NA',
#    'William R. Scott',
#    'Victor A. Nieto',
#    'Elizabeth Holtzman',
#    'Jacob K. Javits'], 'parties': ['free libertarian',
#    'workers world',
#    'republican',
#    'right to life',
#    'conservative',
#    'NA',
#    'communist',
#    'socialist workers',
#    'democrat',
#    'liberal'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False], 'votes': [21465,
#    3643,
#    2272082,
#    152470,
#    275100,
#    73,
#    4161,
#    2715,
#    2618661,
#    664544], 'totalvotes': 6014914},
#  (1980,
#   'North Carolina'): {'names': ['F. W. (Rick) Pasotto',
#    'Robert Morgan',
#    'John P. East',
#    'Rebecca Finch'], 'parties': ['libertarian',
#    'democrat',
#    'republican',
#    'socialist workers'], 'writeins': [False,
#    False,
#    False,
#    False], 'votes': [7602, 887653, 898064, 4346], 'totalvotes': 1797665},
#  (1980,
#   'Ohio'): {'names': ['James E. Betts',
#    'John E. Powers',
#    'John Glenn',
#    'NA'], 'parties': ['republican',
#    'independent',
#    'democrat',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [1137695,
#    76412,
#    2770786,
#    42410], 'totalvotes': 4027303},
#  (1980,
#   'Oklahoma'): {'names': ['Robert Murphy',
#    'Don Nickles',
#    'Charles Nesbitt',
#    'Paul E. Trent',
#    'Andy Coats'], 'parties': ['libertarian',
#    'republican',
#    'independent',
#    'independent',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [9757, 587252, 21179, 1823, 478283], 'totalvotes': 1098294},
#  (1980,
#   'Oregon'): {'names': ['Ted Kulongoski',
#    'Bob Packwood',
#    'NA',
#    'Tonie Nathan'], 'parties': ['democrat',
#    'republican',
#    'NA',
#    'libertarian'], 'writeins': [False, False, True, False], 'votes': [501963,
#    594290,
#    555,
#    43686], 'totalvotes': 1140494},
#  (1980,
#   'Pennsylvania'): {'names': ['Pete Flaherty',
#    'Linda Mohrbacher',
#    'Lee Frissell',
#    'Arlen Specter',
#    'Frank Kinces',
#    'David K. Walter'], 'parties': ['democrat',
#    'socialist workers',
#    'citizens',
#    'republican',
#    'communist',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [2122391,
#    27229,
#    16089,
#    2230404,
#    3334,
#    18595], 'totalvotes': 4418042},
#  (1980,
#   'South Carolina'): {'names': ['Marshall Mays',
#    'Ernest Fritz Hollings'], 'parties': ['republican',
#    'democrat'], 'writeins': [False, False], 'votes': [257946,
#    612554], 'totalvotes': 870500},
#  (1980,
#   'South Dakota'): {'names': ['James Abdnor',
#    'George McGovern',
#    'Wayne Peterson'], 'parties': ['republican',
#    'democrat',
#    'independent'], 'writeins': [False, False, False], 'votes': [190594,
#    129018,
#    7866], 'totalvotes': 327478},
#  (1980,
#   'Utah'): {'names': ['Bruce Bangerter',
#    'Jake Garn',
#    'George M. Batchelor',
#    'Dan Berman'], 'parties': ['independent',
#    'republican',
#    'american',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [3186,
#    437675,
#    1983,
#    151454], 'totalvotes': 594298},
#  (1980,
#   'Vermont'): {'names': ['Stewart M. Ledbetter',
#    'Anthony N. Doria',
#    'Patrick J. Leahy',
#    'Earl S. Gardiner',
#    'NA'], 'parties': ['republican',
#    'independent',
#    'democrat',
#    'socialist',
#    'NA'], 'writeins': [False, False, False, False, True], 'votes': [101421,
#    1776,
#    104176,
#    1629,
#    122], 'totalvotes': 209124},
#  (1980, 'Washington'): {'names': ['Warren G. Magnuson', 'Slade Gorton'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [792052, 936317],
#   'totalvotes': 1728369},
#  (1980,
#   'Wisconsin'): {'names': ['NA',
#    'Robert W. Kasten Jr.',
#    'Gaylord A. Nelson',
#    'Susan L. Hagen',
#    'Bervin J. Larson',
#    'James P. Wickstrom'], 'parties': ['NA',
#    'republican',
#    'democrat',
#    'socialist workers',
#    'libertarian',
#    'american independent'], 'writeins': [True,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [67,
#    1106311,
#    1065487,
#    6502,
#    9679,
#    16156], 'totalvotes': 2204202},
#  (1982,
#   'Arizona'): {'names': ['Dennis DeConcini',
#    'NA',
#    'Pete Dunn',
#    'Randall "Pete Bardo" Clamons'], 'parties': ['democrat',
#    'NA',
#    'republican',
#    'libertarian'], 'writeins': [False, True, False, False], 'votes': [411970,
#    66,
#    291749,
#    20100], 'totalvotes': 723885},
#  (1982,
#   'California'): {'names': ['Theresa "Tena" Dietrich',
#    'David Wald',
#    'Joseph Fuhrig',
#    'Edmund G. Brown, Jr.',
#    'Pete Wilson'], 'parties': ['american independent',
#    'peace and freedom',
#    'libertarian',
#    'democrat',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [83809, 96388, 107720, 3494968, 4022565], 'totalvotes': 7805450},
#  (1982,
#   'Connecticut'): {'names': ['Anthony Toby Moffett',
#    'James A. Lewis',
#    'Lucien P. DiFazio, Jr.',
#    'Lowell P. Weicker, Jr.'], 'parties': ['democrat',
#    'libertarian',
#    'conservative',
#    'republican'], 'writeins': [False, False, False, False], 'votes': [499146,
#    8163,
#    30212,
#    545987], 'totalvotes': 1083508},
#  (1982,
#   'Delaware'): {'names': ['David N. Levinson',
#    'William V. Roth, Jr.',
#    'Charles A. Baker',
#    'Lawrence D. Sullivan'], 'parties': ['democrat',
#    'republican',
#    'american',
#    'libertarian'], 'writeins': [False, False, False, False], 'votes': [84413,
#    105357,
#    537,
#    653], 'totalvotes': 190960},
#  (1982, 'Florida'): {'names': ['NA', 'Van B. Poole', 'Lawton Chiles'],
#   'parties': ['NA', 'republican', 'democrat'],
#   'writeins': [True, False, False],
#   'votes': [422, 1015330, 1637667],
#   'totalvotes': 2653419},
#  (1982,
#   'Hawaii'): {'names': ['Spark Matsunaga',
#    'E. Floyd Bernier-Nachtwey',
#    'Clarence J. Brown'], 'parties': ['democrat',
#    'independent',
#    'republican'], 'writeins': [False, False, False], 'votes': [245386,
#    8953,
#    52071], 'totalvotes': 306410},
#  (1982,
#   'Indiana'): {'names': ['Floyd J. Fithian',
#    'Richard G. Lugar',
#    'Raymond James'], 'parties': ['democrat',
#    'republican',
#    'american'], 'writeins': [False, False, False], 'votes': [828400,
#    978301,
#    10586], 'totalvotes': 1817287},
#  (1982, 'Maine'): {'names': ['NA', 'David F. Emery', 'George J. Mitchell'],
#   'parties': ['NA', 'republican', 'democrat'],
#   'writeins': [True, False, False],
#   'votes': [14, 179882, 279819],
#   'totalvotes': 459715},
#  (1982, 'Maryland'): {'names': ['Paul S. Sarbanes', 'Lawrence J. Hogan'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [707356, 407334],
#   'totalvotes': 1114690},
#  (1982,
#   'Massachusetts'): {'names': ['Howard S. Katz',
#    'Ray Shamie',
#    'NA',
#    'Edward M. Kennedy'], 'parties': ['libertarian',
#    'republican',
#    'NA',
#    'democrat'], 'writeins': [False, False, True, False], 'votes': [18878,
#    784602,
#    205,
#    1247084], 'totalvotes': 2050769},
#  (1982,
#   'Michigan'): {'names': ['Donald W. Riegle, Jr.',
#    'Steve Beumer',
#    'Helen Halyard',
#    'NA',
#    'Daniel Eller',
#    'Philip E. Ruppe',
#    'Bette Erwin'], 'parties': ['democrat',
#    'socialist workers',
#    'workers league',
#    'NA',
#    'american independent',
#    'republican',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False], 'votes': [1728793,
#    4335,
#    6085,
#    42,
#    12660,
#    1223288,
#    19131], 'totalvotes': 2994334},
#  (1982,
#   'Minnesota'): {'names': ['Bill Onasch',
#    'Mark Dayton',
#    'Jeffrey M. Miller',
#    'Dave Durenberger',
#    'Fred G. Hewitt'], 'parties': ['socialist workers',
#    'democrat',
#    'new union',
#    'republican',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [5897, 840401, 3300, 949207, 5870], 'totalvotes': 1804675},
#  (1982, 'Mississippi'): {'names': ['John C. Stennis', 'Haley Barbour'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [414099, 230927],
#   'totalvotes': 645026},
#  (1982, 'Missouri'): {'names': ['NA', 'Harriett Woods', 'John C. Danforth'],
#   'parties': ['NA', 'democrat', 'republican'],
#   'writeins': [True, False, False],
#   'votes': [16, 758629, 784876],
#   'totalvotes': 1543521},
#  (1982,
#   'Montana'): {'names': ['Larry Williams',
#    'John Melcher',
#    'Larry Dodge'], 'parties': ['republican',
#    'democrat',
#    'libertarian'], 'writeins': [False, False, False], 'votes': [133789,
#    174861,
#    12412], 'totalvotes': 321062},
#  (1982,
#   'Nebraska'): {'names': ['Edward Zorinsky',
#    'Jim Keck',
#    'NA',
#    'Virginia Walsh'], 'parties': ['democrat',
#    'republican',
#    'NA',
#    'nominated by petition'], 'writeins': [False,
#    False,
#    True,
#    False], 'votes': [363350, 155760, 94, 26443], 'totalvotes': 545647},
#  (1982, 'Nevada'): {'names': ['Chic Hecht', 'Howard Cannon'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [120377, 114720],
#   'totalvotes': 235097},
#  (1982,
#   'New Jersey'): {'names': ['Millicent Fenwick',
#    'Rose Zeidwerg Monyek',
#    'Martin E. Wendelken',
#    'Robert T. Bastien',
#    'Frank R. Lautenberg',
#    'Henry Koch',
#    'Claire Moriarty',
#    'Julius Levin'], 'parties': ['republican',
#    'repeal tf807 (hr4277-79)',
#    'independent',
#    'grassroots',
#    'democrat',
#    'libertarian',
#    'socialist workers',
#    'socialist labor'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [1047626,
#    1830,
#    4745,
#    2955,
#    1117549,
#    9934,
#    3726,
#    5580], 'totalvotes': 2193945},
#  (1982, 'New Mexico'): {'names': ['Harrison H. Schmitt', 'Jeff Bingaman'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [187128, 217682],
#   'totalvotes': 404810},
#  (1982,
#   'New York'): {'names': ['Florence M. Sullivan',
#    'NA',
#    'Steven Wattenmaker',
#    'Florence M. Sullivan',
#    'Daniel P. Moynihan',
#    'James j. McKeown',
#    'Daniel P. Moynihan',
#    'Florence M. Sullivan'], 'parties': ['republican',
#    'NA',
#    'socialist workers',
#    'conservative',
#    'liberal',
#    'free libertarian',
#    'democrat',
#    'right to life'], 'writeins': [False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [1415749,
#    232,
#    15206,
#    175650,
#    142275,
#    23379,
#    3089871,
#    105367], 'totalvotes': 4967729},
#  (1982,
#   'North Dakota'): {'names': ['Gene Knorr',
#    'Anna B. Bourgois',
#    'Quentin N. Burdick'], 'parties': ['republican',
#    'god, family, and country',
#    'democrat'], 'writeins': [False, False, False], 'votes': [89304,
#    8288,
#    164873], 'totalvotes': 262465},
#  (1982,
#   'Ohio'): {'names': ['Philip Herzing',
#    'Paul E. Pfeifer',
#    'Howard M. Metzenbaum',
#    'Alicia Merel'], 'parties': ['libertarian',
#    'republican',
#    'democrat',
#    'independent'], 'writeins': [False, False, False, False], 'votes': [36103,
#    1396790,
#    1923767,
#    38803], 'totalvotes': 3395463},
#  (1982,
#   'Pennsylvania'): {'names': ['Liane Norman',
#    'Kipp Miriam Dawson',
#    'Cyril H. Wecht',
#    'John Heinz',
#    'Barbara I. Karkutt'], 'parties': ['consumer',
#    'socialist workers',
#    'democrat',
#    'republican',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [16530, 18951, 1412965, 2136418, 19244], 'totalvotes': 3604108},
#  (1982, 'Rhode Island'): {'names': ['John H. Chafee', 'Julius C. Michaelson'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [175495, 167283],
#   'totalvotes': 342778},
#  (1982, 'Tennessee'): {'names': ['Robin Beard', 'NA', 'Jim Sasser'],
#   'parties': ['republican', 'NA', 'democrat'],
#   'writeins': [False, True, False],
#   'votes': [479642, 30, 780113],
#   'totalvotes': 1259785},
#  (1982,
#   'Texas'): {'names': ['Lineaus Hooper Lorette',
#    'NA',
#    'Lloyd Bentsen',
#    'John E. Ford',
#    'Jim Collins'], 'parties': ['citizens',
#    'NA',
#    'democrat',
#    'libertarian',
#    'republican'], 'writeins': [False,
#    True,
#    False,
#    False,
#    False], 'votes': [4564, 127, 1818223, 23494, 1256759], 'totalvotes': 3103167},
#  (1982,
#   'Utah'): {'names': ['Lawrence R. Kauffman',
#    'George Mercier',
#    'Orrin G. Hatch',
#    'Ted Wilson'], 'parties': ['american',
#    'libertarian',
#    'republican',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [953,
#    1035,
#    309332,
#    219482], 'totalvotes': 530802},
#  (1982,
#   'Vermont'): {'names': ['Ion Laskaris',
#    'Robert T. Stafford',
#    'Jerry Levy',
#    'Bo Adlerbert',
#    'NA',
#    'Michael Edward Hackett',
#    'James A. Guest'], 'parties': ['citizens',
#    'republican',
#    'liberty union',
#    'libertarian',
#    'NA',
#    'independent',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False], 'votes': [897,
#    84449,
#    774,
#    892,
#    187,
#    1463,
#    79340], 'totalvotes': 168002},
#  (1982,
#   'Virginia'): {'names': ['Paul S. Trible, Jr.',
#    'Richard J. (Dick) Davis',
#    'NA'], 'parties': ['republican', 'democrat', 'NA'], 'writeins': [False,
#    False,
#    True], 'votes': [724571, 690839, 212], 'totalvotes': 1415622},
#  (1982,
#   'Washington'): {'names': ['King Lysen',
#    'Jesse Chiang',
#    'Doug Jewett',
#    'Henry M. Jackson'], 'parties': ['independent',
#    'independent',
#    'republican',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [72297,
#    20251,
#    332273,
#    943655], 'totalvotes': 1368476},
#  (1982,
#   'West Virginia'): {'names': ['William B. Hovland',
#    'Cleve Benedict',
#    'Robert C. Byrd'], 'parties': ['socialist workers',
#    'republican',
#    'democrat'], 'writeins': [False, False, False], 'votes': [4234,
#    173910,
#    387170], 'totalvotes': 565314},
#  (1982,
#   'Wisconsin'): {'names': ['Scott McCallum',
#    'William Osborne Hart',
#    'William Proxmire',
#    'George Liljenfeldt',
#    'Sanford G. Knapp'], 'parties': ['republican',
#    'labor and farm',
#    'democrat',
#    'libertarian',
#    'constitution'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [527355, 21807, 983311, 7947, 4463], 'totalvotes': 1544883},
#  (1982, 'Wyoming'): {'names': ['Malcolm Wallop', 'Rodger McDaniel'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [94725, 72466],
#   'totalvotes': 167191},
#  (1984,
#   'Alabama'): {'names': ['Howell Heflin',
#    'S. D. (Yana) Davis',
#    'Albert Lee Smith'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [860535,
#    12191,
#    498508], 'totalvotes': 1371234},
#  (1984, 'Alaska'): {'names': ['John E. Havelock', 'Other', 'Ted Stevens'],
#   'parties': ['democrat', '', 'republican'],
#   'writeins': [False, False, False],
#   'votes': [58804, 715, 146919],
#   'totalvotes': 206438},
#  (1984, 'Arkansas'): {'names': ['David Pryor', 'Ed Bethune'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [502341, 373615],
#   'totalvotes': 875956},
#  (1984,
#   'Colorado'): {'names': ['William L. "Bill" Armstrong',
#    'David Martin',
#    'Nancy Dick',
#    'Craig Green',
#    'Earl Higgerson'], 'parties': ['republican',
#    'socialist workers',
#    'democrat',
#    'libertarian',
#    'prohibition'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [833821, 2208, 449327, 11077, 1376], 'totalvotes': 1297809},
#  (1984, 'Delaware'): {'names': ['Joseph R. Biden Jr.', 'John M. Burris'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [147831, 98101],
#   'totalvotes': 245932},
#  (1984, 'Georgia'): {'names': ['Mike Hicks', 'Other', 'Sam Nunn'],
#   'parties': ['republican', '', 'democrat'],
#   'writeins': [False, False, False],
#   'votes': [337196, 44, 1344104],
#   'totalvotes': 1681344},
#  (1984,
#   'Idaho'): {'names': ['Peter M. Busch',
#    'Donald B. Billings',
#    'James A. McClure'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [105591,
#    7384,
#    293193], 'totalvotes': 406168},
#  (1984,
#   'Illinois'): {'names': ['Nelson Gonzalez',
#    'Other',
#    'Charles H. Percy',
#    'Steven I. Givot',
#    'Paul Simon',
#    'Marjorie H. Pries',
#    'Ishmael Flory'], 'parties': ['socialist workers',
#    '',
#    'republican',
#    'libertarian',
#    'democrat',
#    'citizens',
#    'communist'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [4913,
#    273,
#    2308039,
#    59777,
#    2397165,
#    12366,
#    4802], 'totalvotes': 4787335},
#  (1984,
#   'Iowa'): {'names': ['Roger W. Jepsen',
#    'Garry De Young',
#    'Other',
#    'Tom Harkin'], 'parties': ['republican',
#    'independent',
#    '',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [564381,
#    11014,
#    422,
#    716883], 'totalvotes': 1292700},
#  (1984,
#   'Kansas'): {'names': ['James R. Maher',
#    'Freda H. Steele',
#    'Marian Ruck Jackson',
#    'Douglas N. Merritt',
#    'Lucille Bieger',
#    'Nancy Landon Kassebaum'], 'parties': ['democrat',
#    'prohibition',
#    'american',
#    'libertarian',
#    'communist',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [211664,
#    4610,
#    6918,
#    6755,
#    9380,
#    757402], 'totalvotes': 996729},
#  (1984,
#   'Kentucky'): {'names': ['Walter (Dee) Huddleston',
#    'Dave Welters',
#    'Mitch McConnell'], 'parties': ['democrat',
#    'socialist workers',
#    'democrat'], 'writeins': [False, False, False], 'votes': [639721,
#    7696,
#    644990], 'totalvotes': 1292407},
#  (1984, 'Louisiana'): {'names': ['J. Bennett Johnston Jr.'],
#   'parties': ['democrat'],
#   'writeins': [False],
#   'votes': [1],
#   'totalvotes': 1},
#  (1984,
#   'Maine'): {'names': ['P. Ann Stoddard',
#    'William S. Cohen',
#    'Elizabeth H. Mitchell',
#    'Other'], 'parties': ['constitutionalist',
#    'republican',
#    'democrat',
#    ''], 'writeins': [False, False, False, False], 'votes': [4338,
#    404414,
#    142626,
#    28], 'totalvotes': 551406},
#  (1984,
#   'Massachusetts'): {'names': ['Other',
#    'John F. Kerry',
#    'Raymond Shamie'], 'parties': ['',
#    'democrat',
#    'republican'], 'writeins': [False, False, False], 'votes': [408,
#    1393150,
#    1136913], 'totalvotes': 2530471},
#  (1984,
#   'Michigan'): {'names': ['Lynn Johnston',
#    'Max Dean',
#    'Arthur Richard Tisch',
#    'Other',
#    'Carl Levin',
#    'Samuel L. Webb',
#    'William Roundtree',
#    'Helen Meyers',
#    'Fred Mazelis',
#    'Jack Lousma'], 'parties': ['libertarian',
#    'independent',
#    'tisch independent citizens',
#    '',
#    'democrat',
#    'communist',
#    'workers world',
#    'socialist workers',
#    'workers league',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [7786,
#    2135,
#    22882,
#    23,
#    1915831,
#    1196,
#    2279,
#    2686,
#    818,
#    1745302], 'totalvotes': 3700938},
#  (1984,
#   'Minnesota'): {'names': ['Other',
#    'Joan Anderson Growe',
#    'Richard Putman',
#    'Eleanor Garcia',
#    'Jeffrey M. Miller',
#    'Rudy Boschwitz'], 'parties': ['',
#    'democrat',
#    'libertarian',
#    'socialist workers',
#    'new union',
#    'republican'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [240,
#    852844,
#    4653,
#    5351,
#    3129,
#    1199926], 'totalvotes': 2066143},
#  (1984, 'Mississippi'): {'names': ['William F. Winter', 'Thad Cochran'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [371926, 580314],
#   'totalvotes': 952240},
#  (1984, 'Montana'): {'names': ['Neil Halprin', 'Max Baucus', 'Chuck Cozzens'],
#   'parties': ['libertarian', 'democrat', 'republican'],
#   'writeins': [False, False, False],
#   'votes': [9143, 215704, 154308],
#   'totalvotes': 379155},
#  (1984, 'Nebraska'): {'names': ['Other', 'J. J. Exon', 'Nancy Hoch'],
#   'parties': ['', 'democrat', 'republican'],
#   'writeins': [False, False, False],
#   'votes': [304, 332217, 307147],
#   'totalvotes': 639668},
#  (1984,
#   'New Hampshire'): {'names': ["Norman E. D'Amours",
#    'Gordon J. Humphrey',
#    'Saunder H. Primack'], 'parties': ['democrat',
#    'republican',
#    'libertarian'], 'writeins': [False, False, False], 'votes': [157447,
#    225828,
#    1094], 'totalvotes': 384369},
#  (1984,
#   'New Jersey'): {'names': ['Harold F. Leiendecker',
#    'Bill Bradley',
#    'James T. Hagen',
#    'Mary V. Mochary',
#    'Jasper C. Gould',
#    'Julius Levin',
#    'Priscilla Schenk'], 'parties': ['libertarian',
#    'democrat',
#    'prolife fiscal conservative',
#    'republican',
#    'contempt of court',
#    'socialist labor',
#    'socialist workers'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [7135,
#    1986644,
#    10409,
#    1080100,
#    2891,
#    6053,
#    3224], 'totalvotes': 3096456},
#  (1984,
#   'New Mexico'): {'names': ['Pete V. Domenici',
#    'Other',
#    'Judith A. Pratt'], 'parties': ['republican',
#    '',
#    'democrat'], 'writeins': [False, False, False], 'votes': [361371,
#    10,
#    141253], 'totalvotes': 502634},
#  (1984,
#   'North Carolina'): {'names': ['Jesse Helms',
#    'Kate Daher',
#    'Bobby Yates Emory',
#    'James B. (Jim) Hunt Jr.'], 'parties': ['republican',
#    'socialist workers',
#    'libertarian',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [1156768,
#    2493,
#    9302,
#    1070488], 'totalvotes': 2239051},
#  (1984,
#   'Oklahoma'): {'names': ['David Boren',
#    'Robert T. Murphy',
#    'Will E. Bill Crozier'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [906131,
#    11168,
#    280638], 'totalvotes': 1197937},
#  (1984,
#   'Oregon'): {'names': ['Mark O. Hatfield',
#    'Margie Hendriksen',
#    'Other'], 'parties': ['republican', 'democrat', ''], 'writeins': [False,
#    False,
#    False], 'votes': [808152, 406122, 461], 'totalvotes': 1214735},
#  (1984,
#   'Rhode Island'): {'names': ['Barbara M. Leonard',
#    'Claiborne deB. Pell'], 'parties': ['republican',
# ...
#    False], 'votes': [495079,
#    14208,
#    521994,
#    10740,
#    17128,
#    42257,
#    6888], 'totalvotes': 1108294},
#  (2016,
#   'New Hampshire'): {'names': ['Kelly Ayotte',
#    'Maggie Hassan',
#    'scatter',
#    'Brian Chabot',
#    'Aaron Day'], 'parties': ['republican',
#    'democrat',
#    '',
#    'libertarian',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [353632, 354649, 520, 12597, 17742], 'totalvotes': 739140},
#  (2016,
#   'New York'): {'names': ['Alex Merced',
#    'Charles E. Schumer',
#    'Wendy Long',
#    'Blank Vote',
#    'Void Vote',
#    'Wendy Long',
#    'Charles E. Schumer',
#    'scatter',
#    'Charles E. Schumer',
#    'Wendy Long',
#    'Robin Laverne Wilson',
#    'Charles E. Schumer'], 'parties': ['libertarian',
#    'working families',
#    'republican',
#    '',
#    '',
#    'reform',
#    "women's equality",
#    '',
#    'democrat',
#    'conservative',
#    'green',
#    'independence'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [48121,
#    241672,
#    1723927,
#    400943,
#    3474,
#    17813,
#    45402,
#    3472,
#    4784220,
#    267613,
#    113413,
#    150655], 'totalvotes': 7800725},
#  (2016,
#   'North Carolina'): {'names': ['Deborah K. Ross',
#    'Richard Burr',
#    'Sean Haugh'], 'parties': ['democrat',
#    'republican',
#    'libertarian'], 'writeins': [False, False, False], 'votes': [2128165,
#    2395376,
#    167592], 'totalvotes': 4691133},
#  (2016,
#   'North Dakota'): {'names': ['NA',
#    'James Germalic',
#    'John Hoeven',
#    'Eliot Glassheim',
#    'Robert N. Marquette'], 'parties': ['NA',
#    'independent',
#    'republican',
#    'democrat',
#    'libertarian'], 'writeins': [True,
#    False,
#    False,
#    False,
#    False], 'votes': [366, 4675, 268788, 58116, 10556], 'totalvotes': 342501},
#  (2016,
#   'Ohio'): {'names': ['NA',
#    'Scott Rupert',
#    'Ted Strickland',
#    'Joseph R. DeMare',
#    'Tom Connors',
#    'Rob Portman'], 'parties': ['NA',
#    'none',
#    'democrat',
#    'green',
#    'none',
#    'republican'], 'writeins': [True,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [111,
#    77291,
#    1996908,
#    88246,
#    93041,
#    3118567], 'totalvotes': 5374164},
#  (2016,
#   'Oklahoma'): {'names': ['Mike Workman',
#    'James Lankford',
#    'Sean Braddy',
#    'Robert T. Murphy',
#    'Mark T. Beard'], 'parties': ['democrat',
#    'republican',
#    'independent',
#    'libertarian',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [355911, 980892, 40405, 43421, 27418], 'totalvotes': 1448047},
#  (2016,
#   'Oregon'): {'names': ['Eric Navickas',
#    'Other',
#    'Ron Wyden',
#    'Shanti S. Lewallen',
#    'Steven C. Reynolds',
#    'Mark Callahan',
#    'Jim Lindsay'], 'parties': ['pacific green',
#    '',
#    'democrat',
#    'working families',
#    'independent',
#    'republican',
#    'libertarian'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [48823,
#    2058,
#    1105119,
#    61915,
#    59516,
#    651106,
#    23941], 'totalvotes': 1952478},
#  (2016,
#   'Pennsylvania'): {'names': ['Katie McGinty',
#    'Edward T. Clifford III',
#    'Patrick J. Toomey'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [2865012,
#    235142,
#    2951702], 'totalvotes': 6051856},
#  (2016,
#   'South Carolina'): {'names': ['Thomas Dixon',
#    'Bill Bledsoe',
#    'Thomas Dixon',
#    'Bill Bledsoe',
#    'Tim Scott',
#    'NA',
#    'Rebel Michael Scarborough',
#    'Thomas Dixon'], 'parties': ['democrat',
#    'libertarian',
#    'working families',
#    'constitution',
#    'republican',
#    'NA',
#    'american',
#    'green'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False], 'votes': [704540,
#    24830,
#    37610,
#    12652,
#    1241609,
#    1857,
#    11923,
#    14872], 'totalvotes': 2049893},
#  (2016, 'South Dakota'): {'names': ['John R. Thune', 'Jay Williams'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [265516, 104140],
#   'totalvotes': 369656},
#  (2016,
#   'Utah'): {'names': ['Mike Lee',
#    'Bill Barron',
#    'Stoney Fonua',
#    'Misty K. Snow'], 'parties': ['republican',
#    'none',
#    'independent american',
#    'democrat'], 'writeins': [False, False, False, False], 'votes': [760220,
#    26166,
#    27339,
#    301858], 'totalvotes': 1115583},
#  (2016,
#   'Vermont'): {'names': ['Void Vote',
#    'Scott Milne',
#    'Cris Ericson',
#    'Jerry Trudell',
#    'Pete Diamondstone',
#    'Blank Vote',
#    'NA',
#    'Patrick J. Leahy'], 'parties': ['',
#    'republican',
#    'united states marijuana',
#    'independent',
#    'liberty union',
#    '',
#    'NA',
#    'democrat'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False], 'votes': [466,
#    103637,
#    9156,
#    5223,
#    3241,
#    6192,
#    309,
#    192243], 'totalvotes': 320467},
#  (2016, 'Washington'): {'names': ['Chris Vance', 'Patty Murray'],
#   'parties': ['republican', 'democrat'],
#   'writeins': [False, False],
#   'votes': [1329338, 1913979],
#   'totalvotes': 3243317},
#  (2016,
#   'Wisconsin'): {'names': ['Russ Feingold',
#    'Philip N. Anderson',
#    'NA',
#    'Ron Johnson',
#    'scatter'], 'parties': ['democrat',
#    'libertarian',
#    'NA',
#    'republican',
#    ''], 'writeins': [False, False, True, False, False], 'votes': [1380335,
#    87531,
#    8,
#    1479471,
#    1396], 'totalvotes': 2948741},
#  (2018,
#   'Arizona'): {'names': ['Martha McSally',
#    'Kyrsten Sinema',
#    'Angela Green',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'green',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [1135200,
#    1191100,
#    57442,
#    566], 'totalvotes': 2384308},
#  (2018, 'California'): {'names': ['Dianne Feinstein', 'Kevin De Leon'],
#   'parties': ['democrat', 'democrat'],
#   'writeins': [False, False],
#   'votes': [6019422, 5093942],
#   'totalvotes': 11113364},
#  (2018,
#   'Connecticut'): {'names': ['Christopher S Murphy',
#    'Matthew Corey',
#    'Christopher S Murphy',
#    'Richard Lion',
#    'Jeff Russell',
#    'NA'], 'parties': ['democrat',
#    'republican',
#    'working families',
#    'libertarian',
#    'green',
#    'NA'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True], 'votes': [787685, 545717, 37894, 8838, 6618, 88], 'totalvotes': 1386840},
#  (2018,
#   'Delaware'): {'names': ['Thomas R Carper',
#    'Robert B Arlett',
#    'Demitri G Theodoropoulos',
#    'Nadine M Frost'], 'parties': ['democrat',
#    'republican',
#    'green',
#    'libertarian'], 'writeins': [False, False, False, False], 'votes': [217385,
#    137127,
#    4170,
#    3910], 'totalvotes': 362592},
#  (2018, 'Florida'): {'names': ['Rick Scott', 'Bill Nelson', 'NA'],
#   'parties': ['republican', 'democrat', 'NA'],
#   'writeins': [False, False, True],
#   'votes': [4099505, 4089472, 1028],
#   'totalvotes': 8190005},
#  (2018, 'Hawaii'): {'names': ['Mazie K. Hirono', 'Ron Curtis'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [276316, 112035],
#   'totalvotes': 388351},
#  (2018,
#   'Indiana'): {'names': ['Mike Braun',
#    'Joe Donnelly',
#    'Lucy M. Brenton',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [1158000,
#    1023553,
#    100942,
#    70], 'totalvotes': 2282565},
#  (2018,
#   'Maine'): {'names': ['Eric L. Brakey',
#    'Angus S. King, Jr.',
#    'Zak Ringelstein',
#    'Others'], 'parties': ['republican',
#    'independent',
#    'democrat',
#    'NA'], 'writeins': [False, False, False, False], 'votes': [223502,
#    344575,
#    66268,
#    64], 'totalvotes': 634409},
#  (2018,
#   'Maryland'): {'names': ['Tony Campbell',
#    'Ben Cardin',
#    'Arvin Vohra',
#    'Neal Simon',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'unaffiliated',
#    'NA'], 'writeins': [False, False, False, False, True], 'votes': [697017,
#    1491614,
#    22943,
#    85964,
#    2351], 'totalvotes': 2299889},
#  (2018,
#   'Massachusetts'): {'names': ['Elizabeth A. Warren',
#    'Geoff Diehl',
#    'Shiva Ayyadurai',
#    'Others'], 'parties': ['democrat',
#    'republican',
#    'unenrolled',
#    'NA'], 'writeins': [False, False, False, False], 'votes': [1633371,
#    979210,
#    91710,
#    2799], 'totalvotes': 2707090},
#  (2018,
#   'Michigan'): {'names': ['John James',
#    'Debbie Stabenow',
#    'George E. Huffman III',
#    'Marcia Squier',
#    'John Howard Wilhelm',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'us taxpayers',
#    'green',
#    'natural law',
#    'NA'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True], 'votes': [1938818, 2214478, 27251, 40204, 16502, 18], 'totalvotes': 4237271},
#  (2018,
#   'Minnesota'): {'names': ['Jim Newberger',
#    'Amy Klobuchar',
#    'Dennis Schuller',
#    'Paula M Overby',
#    'NA'], 'parties': ['republican',
#    'democratic-farmer-labor',
#    'legal marijuana now',
#    'minnesota green',
#    'NA'], 'writeins': [False, False, False, False, True], 'votes': [940437,
#    1566174,
#    66236,
#    23101,
#    931], 'totalvotes': 2596879},
#  (2018,
#   'Mississippi'): {'names': ['David Baria',
#    'Roger F. Wicker',
#    'Danny Bedwell',
#    "Shawn O'Hara"], 'parties': ['democrat',
#    'republican',
#    'libertarian',
#    'reform'], 'writeins': [False, False, False, False], 'votes': [369567,
#    547619,
#    12981,
#    6048], 'totalvotes': 936215},
#  (2018,
#   'Missouri'): {'names': ['Josh Hawley',
#    'Claire McCaskill',
#    'Japheth Campbell',
#    'Jo Crain',
#    "Craig O'Dear",
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'green',
#    'independent',
#    'NA'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    True], 'votes': [1254927, 1112935, 27316, 12706, 34398, 7], 'totalvotes': 2442289},
#  (2018,
#   'Montana'): {'names': ['Jon Tester',
#    'Rick Breckenridge',
#    'Matt Rosendale'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [253876,
#    14545,
#    235963], 'totalvotes': 504384},
#  (2018,
#   'Nebraska'): {'names': ['Deb Fischer',
#    'Jane Raybould',
#    'Jim Schultz',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [403151,
#    269917,
#    25349,
#    466], 'totalvotes': 698883},
#  (2018,
#   'Nevada'): {'names': ['Jacky Rosen',
#    'Dean Heller',
#    'None of these Candidates',
#    'Barry Michaels',
#    'Tim Hagan',
#    'Kamau A. Bakari'], 'parties': ['democrat',
#    'republican',
#    'NA',
#    'independent',
#    'libertarian',
#    'independent american'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [490071,
#    441202,
#    15303,
#    9269,
#    9196,
#    7091], 'totalvotes': 972132},
#  (2018,
#   'New Jersey'): {'names': ['Robert Menendez',
#    'Bob Hugin',
#    'Madelyn R. Hoffman',
#    'Murray Sabrin',
#    'Natalie Lynn Rivera',
#    'Tricia Flanagan',
#    'Kevin Kimple',
#    'Hank Schroeder'], 'parties': ['democrat',
#    'republican',
#    'green',
#    'libertarian',
#    'for the people',
#    'new day nj',
#    'make it simple',
#    'economic growth'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [1711654,
#    1357355,
#    25150,
#    21212,
#    19897,
#    16101,
#    9087,
#    8854], 'totalvotes': 3169310},
#  (2018,
#   'New Mexico'): {'names': ['Martin T Heinrich',
#    'Gary E Johnson',
#    'Mick Rich'], 'parties': ['democrat',
#    'libertarian',
#    'republican'], 'writeins': [False, False, False], 'votes': [376998,
#    107201,
#    212813], 'totalvotes': 697012},
#  (2018,
#   'New York'): {'names': ['Kirsten E. Gillibrand',
#    'Chele Chiavacci Farley',
#    'Chele Chiavacci Farley',
#    'Kirsten E. Gillibrand',
#    'Kirsten E. Gillibrand',
#    'Kirsten E. Gillibrand',
#    'Chele Chiavacci Farley'], 'parties': ['democrat',
#    'republican',
#    'conservative',
#    'working families',
#    'independence',
#    "women's equality",
#    'reform'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [3755489,
#    1730439,
#    246171,
#    160128,
#    99325,
#    41989,
#    21610], 'totalvotes': 6055151},
#  (2018, 'North Dakota'): {'names': ['Kevin Cramer', 'Heidi Heitkamp', 'NA'],
#   'parties': ['republican', 'democratic-npl', 'NA'],
#   'writeins': [False, False, True],
#   'votes': [179720, 144376, 2042],
#   'totalvotes': 326138},
#  (2018, 'Ohio'): {'names': ['Sherrod Brown', 'NA', 'Jim Renacci'],
#   'parties': ['democrat', 'NA', 'republican'],
#   'writeins': [False, True, False],
#   'votes': [2355923, 1012, 2053963],
#   'totalvotes': 4410898},
#  (2018,
#   'Pennsylvania'): {'names': ['Robert P Casey Jr',
#    'Louis J. Barletta',
#    'Neal Taylor Gale',
#    'Dale R Kerns Jr'], 'parties': ['democrat',
#    'republican',
#    'green',
#    'libertarian'], 'writeins': [False, False, False, False], 'votes': [2777680,
#    2134848,
#    31208,
#    50907], 'totalvotes': 4994643},
#  (2018,
#   'Rhode Island'): {'names': ['Sheldon Whitehouse',
#    'Robert G. Flanders, Jr.',
#    'NA'], 'parties': ['democrat', 'republican', 'NA'], 'writeins': [False,
#    False,
#    True], 'votes': [231477, 144421, 840], 'totalvotes': 376738},
#  (2018,
#   'Tennessee'): {'names': ['Marsha Blackburn',
#    'Phil Bredesen',
#    'Trudy A. Austin',
#    'John Carico',
#    'Dean Hill',
#    'Kevin Lee McCants',
#    'Breton Phillips',
#    'Kris L. Todd'], 'parties': ['republican',
#    'democrat',
#    'independent',
#    'independent',
#    'independent',
#    'independent',
#    'independent',
#    'independent'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False], 'votes': [1227483,
#    985450,
#    9455,
#    3398,
#    8717,
#    1927,
#    2226,
#    5084], 'totalvotes': 2243740},
#  (2018, 'Texas'): {'names': ['Ted Cruz', "Beto O'Rourke", 'Neal M. Dikeman'],
#   'parties': ['republican', 'democrat', 'libertarian'],
#   'writeins': [False, False, False],
#   'votes': [4260553, 4045632, 65470],
#   'totalvotes': 8371655},
#  (2018,
#   'Utah'): {'names': ['Mitt Romney',
#    'Jenny Wilson',
#    'Tim Aalders',
#    'Craig R. Bowden',
#    'Reed C. McCandless'], 'parties': ['republican',
#    'democrat',
#    'constitution',
#    'libertarian',
#    'independent american'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False], 'votes': [665215,
#    328541,
#    28774,
#    27607,
#    12708], 'totalvotes': 1062845},
#  (2018,
#   'Vermont'): {'names': ['Folasade Adeluola',
#    'Russell Beste',
#    'Bruce Busa',
#    'Edward S. Gilbert Jr',
#    'Reid Kane',
#    'Brad J. Peacock',
#    'Bernie Sanders',
#    'Jon Svitavsky',
#    'Lawrence Zupan',
#    'NA'], 'parties': ['independent',
#    'independent',
#    'independent',
#    'independent',
#    'liberty union',
#    'independent',
#    'independent',
#    'independent',
#    'republican',
#    'NA'], 'writeins': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True], 'votes': [1979,
#    2763,
#    914,
#    2244,
#    1171,
#    3787,
#    183529,
#    1280,
#    74663,
#    294], 'totalvotes': 272624},
#  (2018,
#   'Virginia'): {'names': ['Corey A. Stewart',
#    'Timothy M. Kaine',
#    'Matt J. Waters',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [1374313,
#    1910370,
#    61565,
#    5125], 'totalvotes': 3351373},
#  (2018, 'Washington'): {'names': ['Maria Cantwell', 'Susan Hutchison'],
#   'parties': ['democrat', 'republican'],
#   'writeins': [False, False],
#   'votes': [1803364, 1282804],
#   'totalvotes': 3086168},
#  (2018,
#   'West Virginia'): {'names': ['Joe Manchin',
#    'Patrick Morrisey',
#    'Rusty Hollen'], 'parties': ['democrat',
#    'republican',
#    'libertarian'], 'writeins': [False, False, False], 'votes': [288808,
#    269872,
#    24231], 'totalvotes': 582911},
#  (2018, 'Wisconsin'): {'names': ['Tammy Baldwin', 'Leah Vukmir', 'NA'],
#   'parties': ['democrat', 'republican', 'NA'],
#   'writeins': [False, False, True],
#   'votes': [1472914, 1184885, 42],
#   'totalvotes': 2657841},
#  (2018,
#   'Wyoming'): {'names': ['John Barrasso',
#    'Gary Trauner',
#    'Joseph Porambo',
#    'NA'], 'parties': ['republican',
#    'democrat',
#    'libertarian',
#    'NA'], 'writeins': [False, False, False, True], 'votes': [136210,
#    61227,
#    5658,
#    325], 'totalvotes': 203420}}

# %% [markdown]
# ### electionExists
#
# Write a predicate called `electionExists` that determines whether an election was held in a particular state and year.

# %%
def electionExists(year, state):
    # Your code here
    return (year, state) in senateDct

# %%
electionExists(1986, "Maryland") # should be True
# Out:
# True

# %%
electionExists(1978, "Hawaii") # should be False
# Out:
# False

# %%
electionExists(1976, "Hawaii") # should be True
# Out:
# True

# %% [markdown]
# ### mostVotesCast

# %% [markdown]
# Write a function called `mostVotesCast` that iterates through the senateDct and determines which election as a tuple (year and state) had the most votes cast.
#
# **Hint**: it's likely to be California but which year?

# %%
def mostVotesCast():
    # Your code here
    mostVotes = 0
    election = None
    for year, state in senateDct:
        electionDct = senateDct[(year, state)]
        total = electionDct["totalvotes"]
        if total > mostVotes:
            election = year, state
            mostVotes = total
    return election

# %% [markdown]
# You can check your answer below by scrolling down to the end of the notebook.

# %%
mostVotesCast()
# Out:
# (2012, 'California')

# %% [markdown]
# ### Number of Different Political Parties
#
# America has actually had quite a number of different political parties over the course of its history, most of them with relatively small numbers.  Write a function `listPoliticalParties` that returns a list of all the parties represented in Senate elections from 1976-2018.  Your list should contain unique entries.  For example, `'republican'` should only be included once.

# %%
def listPoliticalParties():
    # Your code here
    listOfParties = []
    for year, state in senateDct:
        electionDct = senateDct[(year, state)]
        partyList = electionDct["parties"]
        for party in partyList:
            if party not in listOfParties:
                listOfParties.append(party)
    return listOfParties

# %%
parties = listPoliticalParties()

# %% [markdown]
# If you look at the data below, you will notice that there are some strange political parties listed like `'none'` and `''`.  These are likely write-in candidates and are not political parties.  So our list won't be entirely accurate.

# %%
parties
# Out:
# ['republican',
#  'independent',
#  'democrat',
#  'libertarian',
#  'american independent',
#  'peace and freedom',
#  '',
#  'american',
#  'prohibition',
#  'none',
#  'u.s. labor',
#  'socialist workers',
#  'human rights',
#  'socialist labor',
#  'communist',
#  'NA',
#  'independent american',
#  'labor',
#  'la raza unida',
#  'liberal',
#  'conservative',
#  'constitution',
#  'liberty union',
#  'democratic socialist',
#  'national statesman',
#  'united states party',
#  'public interest independent',
#  'workers',
#  'national democratic party of alabama',
#  'statesman',
#  'people before profits',
#  'unaffiliated-american',
#  'citizens',
#  'workers world',
#  'by petition',
#  'no party',
#  'free libertarian',
#  'right to life',
#  'socialist',
#  'workers league',
#  'new union',
#  'nominated by petition',
#  'repeal tf807 (hr4277-79)',
#  'grassroots',
#  'god, family, and country',
#  'consumer',
#  'labor and farm',
#  'constitutionalist',
#  'tisch independent citizens',
#  'prolife fiscal conservative',
#  'contempt of court',
#  'unaffiliated american',
#  'illinois solidarity',
#  'new alliance',
#  'third party',
#  'workers against concessions',
#  'progressive issues',
#  'democratic-farmer-labor',
#  'independent progressive line',
#  'populist',
#  'concerns of people',
#  'green',
#  'chsritian pro-life',
#  "perot's independents",
#  'a connecticut party',
#  'concerned citizens',
#  'natural law',
#  'freedom for larouche',
#  'unenrolled',
#  'larouche was right',
#  'independence',
#  'property rights',
#  'keep america first',
#  'damn drug dealers',
#  'independence fusion',
#  'patriot',
#  'reform',
#  'u.s. taxpayers',
#  'socialist equality',
#  'resource',
#  'u.s. pacifist',
#  'american constitution',
#  'term limits',
#  'other',
#  'taxpayers',
#  'marijuana reform',
#  'pacific',
#  'constitutional',
#  'vermont grassroots',
#  'timesizing not downsizing',
#  'citizens first',
#  'working families',
#  'democratic-nonpartisan league',
#  'alaskan independence',
#  'independent party of delaware',
#  'alaska libertarian',
#  'nonpartisan',
#  'unaffiliated',
#  'veterans party of america',
#  'builders',
#  'pacific green',
#  'united citizens',
#  'vermont green',
#  'marijuana',
#  'connecticut for lieberman',
#  'progressive',
#  'poor peopleﾇ尽 campaign',
#  'god we trust',
#  'legalize marijuana (g.r.i.p.)',
#  'solidarity',
#  'socialist party usa',
#  'personal choice',
#  'desert greens',
#  'anti-bushist candidate',
#  'independent green',
#  'wisconsin green',
#  'no party affiliation',
#  'american constitution party',
#  'nebraska party',
#  'boss for senate',
#  "poor people's campaign",
#  'nonaffiliated',
#  'independent reform',
#  'constitution party of florida',
#  'tea party of nevada',
#  'united states marijuana',
#  'constitution party of wisconsin',
#  'independent for Maine',
#  'Independent for Liberty',
#  'grassroots party',
#  'minnesota open progressives',
#  'responsibility fairness integrity',
#  'america first',
#  'jersey strong independents',
#  'totally independent candidate',
#  'no slogan',
#  'reform nation',
#  'common sense',
#  'justice',
#  'votekiss',
#  'peace and prosperity',
#  'mountain party',
#  'i.d.e.a.',
#  'country party',
#  'unity party of colorado',
#  'bob quast for term limits',
#  'd-r party',
#  'economic growth',
#  'petition',
#  'mountain',
#  'american shopping party',
#  'new independent party iowa',
#  "women's equality",
#  'us taxpayers',
#  'legal marijuana now',
#  'minnesota green',
#  'for the people',
#  'new day nj',
#  'make it simple',
#  'democratic-npl']

# %%
print("The number of different political parties running for senate " +
      "from 1976-2018 is roughly " + str(len(parties)) + ".")
# Out:
# The number of different political parties running for senate from 1976-2018 is roughly 160.

# %% [markdown]
# ### Election Winner
#
# Write a function called `electionWinner` that takes a year and state and returns who won that election.  If an election did not take place during that year/state, `electionWinner` should return the string `'Unknown'`. If the election did take place, the winner should be returned as a tuple with the elements of name, party, and percent of vote won.  Round the percent to the hundreds place.
#
# You may find the method `.index` helpful when solving this problem.  The `.index` method returns the index of some value in a sequence.  Therefore, the `.index` method is a appropriate for any sequence.

# %%
"ABC".index("B")
# Out:
# 1

# %%
["A", "B", "C"].index("A")
# Out:
# 0

# %%
[45, 1, -1].index(-1)
# Out:
# 2

# %%
(90, True, False, 4.1).index(False)
# Out:
# 2

# %%
range(3, 10, 3).index(6)
# Out:
# 1

# %% [markdown]
# If the value does not exist in the sequence, then a ValueError is raised.

# %%
["A", "B"].index("C")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-6f8aeea42865> in <module>
# ----> 1 ["A", "B"].index("C")
#
# ValueError: 'C' is not in list

# %% [markdown]
# Note you may not need to use the `.index` method when implementing your solution but it can be helpful depending upon your approach.

# %%
def electionWinner(year, state):
    # Your code here
    electDct = senateDct.get((year, state), "Unknown")
    if electDct == "Unknown": return "Unknown"
    
    # compute the index of the max votes
    votesList = electDct["votes"]
    maxVotes = max(votesList)
    index = votesList.index(maxVotes)
    
    # use the index to get the name, party and pct of votes
    name = electDct["names"][index]
    party = electDct["parties"][index]
    pct = round(100 * electDct["votes"][index]/electDct["totalvotes"], 2)
    
    return (name, party, pct)

# %%
electionWinner(1986, "Maryland") # should be ('Barbara A. Mikulski', 'democrat', 60.69)
# Out:
# ('Barbara A. Mikulski', 'democrat', 60.69)

# %%
electionWinner(2006, "Texas") # should be ('Kay Bailey Hutchison', 'republican', 61.69)
# Out:
# ('Kay Bailey Hutchison', 'republican', 61.69)

# %%
electionWinner(2020, "Georgia") # should be Unknown
# Out:
# 'Unknown'

# %%
electionWinner(2016, "Georgia") # should be ('Johnny Isakson', 'republican', 54.78)
# Out:
# ('Johnny Isakson', 'republican', 54.78)

# %% [markdown]
# Curious about another state and year?  Call `electionWinner` below!

# %%
# Your code here
electionWinner(2002, "Mississippi")
# Out:
# ('Thad Cochran', 'republican', 84.58)

# %% [markdown]
# ### thirdCandidates
#
# Write a function called `thirdCandidates` that returns a list of tuples where each tuple represents an election not won by a Democrat or Republican.  Note that in the Senate dictionary that a Republican is the string `'republican'` and a Democrat is the string `'democrat'`.  You should use the function `electionWinner` from above.  Note that the tuple for each election should state the year of the election, the state, the name of the candidate, their party, and the percent of the overall vote that they obtained.

# %%
def thirdCandidates():
    # Your code here
    thirdCandList = []
    for year, state in senateDct:
        name, party, pct = electionWinner(year, state)
        if party != "republican" and party != "democrat":
            thirdCandList.append((year, state, name, party, pct))
    return thirdCandList

# %% [markdown]
# See the answers at the bottom of the notebook to check if your implementation produced the correct list.

# %%
thirdCandidates()
# Out:
# [(1976, 'Virginia', 'Harry F. Byrd, Jr.', 'independent', 57.19),
#  (1996, 'Minnesota', 'Paul Wellstone', 'democratic-farmer-labor', 50.32),
#  (2000, 'Minnesota', 'Mark Dayton', 'democratic-farmer-labor', 48.83),
#  (2000, 'North Dakota', 'Kent Conrad', 'democratic-nonpartisan league', 61.37),
#  (2006,
#   'Connecticut',
#   'Joseph I. Lieberman',
#   'connecticut for lieberman',
#   49.71),
#  (2006, 'Minnesota', 'Amy Klobuchar', 'democratic-farmer-labor', 58.06),
#  (2006, 'Vermont', 'Bernard Sanders', 'independent', 65.41),
#  (2010, 'Alaska', 'Lisa Murkowski', '', 39.57),
#  (2012, 'Maine', 'Angus King', 'independent for Maine', 51.13),
#  (2012, 'Vermont', 'Bernard Sanders', 'independent', 71.0),
#  (2018, 'Maine', 'Angus S. King, Jr.', 'independent', 54.31),
#  (2018, 'Minnesota', 'Amy Klobuchar', 'democratic-farmer-labor', 60.31),
#  (2018, 'Vermont', 'Bernie Sanders', 'independent', 67.32)]

# %% [markdown]
# ### writeInWinners
#
# Below write a function called `writeInWinners` that returns a list of tuples for all Senate candidates who won their seat as a write-in candidate.  You should use the function `electionWinner` from above.  Note that the tuple for each election should state the year of the election, the state, the name of the candidate,  and the percent of the overall vote that they obtained.

# %%
def writeInWinners():
    # Your code here
    writeInList = []
    for year, state in senateDct:
        electionDct = senateDct[year, state]
        name, party, pct = electionWinner(year, state)
        indexOfWinner = electionDct["names"].index(name)
        if electionDct["writeins"][indexOfWinner]:
            writeInList.append((year, state, name, pct))
    return writeInList

# %% [markdown]
# See the answers at the bottom of the notebook to check if your implementation produced the correct list.

# %%
writeInWinners()
# Out:
# [(2010, 'Alaska', 'Lisa Murkowski', 39.57)]

# %% [markdown]
# ## Challenge Problems
#
# These problems are harder and more like problem set questions.
#
# **IMPORTANT**: Do not modify or mutate the Senate dictionary when implementing your solution!

# %% [markdown]
# ### closeRaces
#
# Elections can be quite tight in some years.  Below write a function called `closeRaces` that iterates through the Senate dictionary to find all the close senate races over the years and store those results in a list of tuples. For every close race, the tuple should contain the year of the election, the state, and the margin of victory.  `closesRaces` should take a threshold parameter which indicates the threshold for including an election as a close race.  For example, if the threshold were equal to 4000, then the 1986 Senate election in North Dakota would be included because the highest vote getter (Democrat Kent Conrad) barely beat the second highest vote getter (incumbent Republican Mark Andrews) by only 2,120 votes.

# %%
def closeRaces(threshold):
    # Your code here
    closeRaceList = []
    for year, state in senateDct:
        electionDct = senateDct[(year, state)]
        
        voteList = electionDct["votes"]
        maxVote = max(voteList)
        
        remainingVotes = voteList[:]
        indexOfMax = remainingVotes.index(maxVote)
        remainingVotes.pop(indexOfMax)
        
        for vote in remainingVotes:
            if maxVote - vote <= threshold:
                closeRaceList.append((year, state, maxVote - vote))
    return closeRaceList

# %%
closeRaces(500) # you should have two items
# Out:
# [(1998, 'Nevada', 401), (2008, 'Minnesota', 312)]

# %%
closeRaces(1000) # you should have three items
# Out:
# [(1998, 'Nevada', 401), (2002, 'South Dakota', 532), (2008, 'Minnesota', 312)]

# %%
closeRaces(2000) # you should have five items
# Out:
# [(1988, 'Wyoming', 1322),
#  (1998, 'Nevada', 401),
#  (2002, 'South Dakota', 532),
#  (2008, 'Minnesota', 312),
#  (2016, 'New Hampshire', 1017)]

# %%
closeRaces(4000) # you should have eleven items
# Out:
# [(1980, 'Vermont', 2755),
#  (1986, 'North Dakota', 2120),
#  (1988, 'Wyoming', 1322),
#  (1998, 'Nevada', 401),
#  (2000, 'Washington', 2229),
#  (2002, 'South Dakota', 532),
#  (2006, 'Montana', 3562),
#  (2008, 'Alaska', 3953),
#  (2008, 'Minnesota', 312),
#  (2012, 'North Dakota', 2936),
#  (2016, 'New Hampshire', 1017)]

# %% [markdown]
# ### Third-Party Split
#
# After election results come out, there is often much discussion about how third-party candidates split the vote in tight elections.  Write a function called `thirdPartySplit` that returns a list of elections where if all the votes excluding those for the top two candidates were instead given to the runner-up, that the election outcome would have been different.  The list should contain tuples for each election where the tuple contains the year and state of the election.

# %%
def thirdPartySplit():
    # your code here
    splitList = []
    for year, state in senateDct:
        electionDct = senateDct[(year, state)]
        
        voteList = electionDct["votes"]
        remainingVotes = voteList[:] # make a copy so we don't mutate the original list
        
        maxVote = max(remainingVotes)
        indexOfMax = remainingVotes.index(maxVote)
        remainingVotes.pop(indexOfMax)
        
        if len(remainingVotes) == 0: continue
        secondMaxVote = max(remainingVotes)
        indexOfSecondMax = remainingVotes.index(secondMaxVote)
        remainingVotes.pop(indexOfSecondMax)
        
        totalRemainingVotes = 0
        for vote in remainingVotes:
            totalRemainingVotes += vote
        
        if maxVote <= totalRemainingVotes + secondMaxVote:
            splitList.append((year, state))
    return splitList

# %%
elections = thirdPartySplit()

# %%
elections
# Out:
# [(1976, 'New York'),
#  (1976, 'Ohio'),
#  (1976, 'Vermont'),
#  (1978, 'Mississippi'),
#  (1978, 'Texas'),
#  (1980, 'Arizona'),
#  (1980, 'Idaho'),
#  (1980, 'New York'),
#  (1980, 'North Carolina'),
#  (1980, 'Vermont'),
#  (1984, 'Kentucky'),
#  (1986, 'California'),
#  (1986, 'Colorado'),
#  (1986, 'Nevada'),
#  (1986, 'New York'),
#  (1986, 'North Dakota'),
#  (1988, 'Connecticut'),
#  (1992, 'California'),
#  (1992, 'Connecticut'),
#  (1992, 'Georgia'),
#  (1992, 'New Hampshire'),
#  (1992, 'New York'),
#  (1992, 'Pennsylvania'),
#  (1994, 'California'),
#  (1994, 'Connecticut'),
#  (1994, 'Minnesota'),
#  (1994, 'New York'),
#  (1994, 'Pennsylvania'),
#  (1994, 'Virginia'),
#  (1996, 'Georgia'),
#  (1996, 'Maine'),
#  (1996, 'Montana'),
#  (1996, 'New Hampshire'),
#  (1996, 'Oregon'),
#  (1998, 'Kentucky'),
#  (1998, 'Nevada'),
#  (1998, 'New York'),
#  (2000, 'Michigan'),
#  (2000, 'Minnesota'),
#  (2000, 'Washington'),
#  (2002, 'Louisiana'),
#  (2002, 'Minnesota'),
#  (2002, 'South Dakota'),
#  (2004, 'Alaska'),
#  (2004, 'Florida'),
#  (2006, 'Connecticut'),
#  (2006, 'Missouri'),
#  (2006, 'Montana'),
#  (2006, 'Virginia'),
#  (2008, 'Alaska'),
#  (2008, 'Georgia'),
#  (2008, 'Minnesota'),
#  (2008, 'Oregon'),
#  (2010, 'Alaska'),
#  (2010, 'Colorado'),
#  (2010, 'Florida'),
#  (2012, 'Arizona'),
#  (2012, 'Montana'),
#  (2012, 'Nevada'),
#  (2014, 'Alaska'),
#  (2014, 'Colorado'),
#  (2014, 'Louisiana'),
#  (2014, 'North Carolina'),
#  (2014, 'Virginia'),
#  (2016, 'Alaska'),
#  (2016, 'Colorado'),
#  (2016, 'Louisiana'),
#  (2016, 'Missouri'),
#  (2016, 'Nevada'),
#  (2016, 'New Hampshire'),
#  (2016, 'Pennsylvania'),
#  (2018, 'Arizona'),
#  (2018, 'West Virginia')]

# %% [markdown]
# How many elections could have been changed if the third party vote had gone to the second place finisher?

# %%
print(len(elections))
# Out:
# 73

# %% [markdown]
# ### Other Questions
#
# There are of course plenty of other questions we could ask about the data.  Here are some other interesting questions to try and tackle:
#
# - Which states have consistently elected senators from the same party?
# - Which states have the most flip-flopping between parties?
# - Can we draw any trends about political parties over the years from some states?  Do we see trends from certain states to lean toward one party from another party over time?  Virginia is a good state to analyze.
#
# What other questions could we ask?  If you have time try and tackle some of these questions with your own functions below.

# %%
# Your code here

# %% [markdown]
# ### Answers

# %% [markdown]
# Question: What state and in what year were the most votes cast for a senate race?
# Answer: California, 2012
#
# Question: How many times have senators won their election race who were not registered as democrats and republicans?
# Answer: 13!  Harry F. Byrd Jr., Paul Wellstone, Mark Dayton, Kent Conrad, Joe Lieberman, Amy Klobuchar (2), Bernie Sanders (3), Lisa Murkowski, Angus King (2).
#
# Question: How many times have senators won their election race as a write-in candidate?
# Answer: 1!  Lisa Murkowski
